# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
sns.set_context('notebook', font_scale=1.5)
# %matplotlib inline

# %% [markdown]
# ## Section 1: Simulations

# %%
from tqdm import tqdm
from scipy.stats import spearmanr

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
### Define parameters.
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

## Simulation parameters.
n_sim = 5000
n_sub = 100

## Population distribution.
mixing = [0.85,0.15]
sd = 0.075

## Task behavior distribution. 
mu_tb = [0.75,0.50]

## Self-report behavior distributions.
mu_sr = [
    [0.50,0.50],
    [0.20,0.50]
]

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
### Perform simulations.
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

## Preallocate space.
X = np.zeros((n_sub,2)); Y = np.zeros((n_sub,2))
rvals = np.zeros((n_sim,2)); pvals = np.zeros((n_sim,2))

## Iteratively perform simulations.
for i in range(2):
    
    np.random.seed(0)
    for j in tqdm(range(n_sim)):
        
        ## Sample task behavior.
        y = np.concatenate([np.random.normal(mu,sd,int(n_sub*p)) for mu,p in zip(mu_tb,mixing)])
        y = np.where(y > 1, 1, y)
        if not j: Y[:,i] = y
        
        ## Sample self-report behavior.
        x = np.concatenate([np.random.normal(mu,sd,int(n_sub*p)) for mu,p in zip(mu_sr[i],mixing)])
        x = np.abs(x)
        if not j: X[:,i] = x

        ## Compute correlation.
        rvals[j,i], pvals[j,i] = spearmanr(x, y)
# Out:
# 100%|██████████| 5000/5000 [00:04<00:00, 1139.73it/s]
# 100%|██████████| 5000/5000 [00:04<00:00, 1185.56it/s]

# %% [markdown]
# ## Section 2: Plotting

# %%
import matplotlib.gridspec as gridspec
from scipy.stats import norm

## Initialize canvas.
fig = plt.figure(figsize=(12,6))

## Initialize panels.
panel_1 = fig.add_gridspec(nrows=3, ncols=1, left=0.00, right=0.12, wspace=0, hspace=0)
panel_2 = fig.add_gridspec(nrows=3, ncols=2, left=0.12, right=0.50, wspace=0, hspace=0)
panel_3 = fig.add_gridspec(nrows=3, ncols=2, left=0.56, right=0.92, wspace=0, hspace=0)

## Define features.
hue = np.concatenate([np.repeat(i,int(n_sub*p)) for i, p in enumerate(mixing)])
palette = ['#AA3939','#2E4272']
x = np.linspace(0,1,1001)

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
### Panel 1: y-margins.
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

## Initialize axis.
ax = plt.subplot(panel_1[1:,0])

## Iteratively plot distributions.
for p, m, color in zip(mixing, mu_tb, palette):
    y = norm(m,sd).pdf(x) * p
    ax.plot(y, x, color=color)
    ax.fill_betweenx(x, y, -1, color=color, alpha=0.7)

## Add details.
ax.set(xlim=(5e-2), xticks=[], ylim=(0.2,1.01), yticks=[])
ax.invert_xaxis()
sns.despine(left=True, bottom=True, top=True, right=True, ax=ax)

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
### Panel 2: x-margins.
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

## Initialize axis.
ax = plt.subplot(panel_2[0,:])

## Iteratively plot distributions.
for p, m, color in zip(mixing, mu_sr[0], palette):
    y = norm(m,sd).pdf(x) * p
    ax.plot(x, y, color=color)
    ax.fill_between(x, y, -1, color=color, alpha=0.7)

## Add details.
ax.set(xlim=(0.00,0.80), xticks=[], ylim=(5e-2), yticks=[])
sns.despine(left=True, bottom=True, top=True, right=True, ax=ax)

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
### Panel 2: scatterplot.
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

## Initialize axis.
ax = plt.subplot(panel_2[1:,:])

## Plot scatterplot.
ax.set(xlim=(0.00,0.80), ylim=(0.2,1.01), yticks=[])
sns.scatterplot(x=X[:,0], y=Y[:,0], hue=hue, palette=palette, ax=ax)
sns.regplot(x=X[:,0], y=Y[:,0], scatter=False, ci=None, truncate=False, 
            color='k', line_kws=dict(lw=0.9, linestyle='--', zorder=-1), ax=ax)

## Add details.
ax.set(xlabel='Self-Report Symptom Scores')

## Add legend.
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['Attentive','Careless'], loc=3, ncol=2, frameon=False, 
          borderaxespad=0.1, handletextpad=0, columnspacing=0.5)

## Add annotation.
rho = rvals[:,0].mean()
fpr = (pvals[:,0] < 0.05).mean()
annot = r'Mean $\hat{\rho}$ = %0.3f' %rho + '\nFPR = %0.3f' %fpr
ax.annotate(annot, (0,0), (0.02, 0.95), xycoords='axes fraction', ha='left', va='top', fontsize=14)

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
### Panel 3: x-marigns.
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

## Initialize axis.
ax = plt.subplot(panel_3[0,:])

## Iteratively plot distributions.
for p, m, color in zip(mixing, mu_sr[1], palette):
    y = norm(m,sd).pdf(x) * p
    ax.plot(x, y, color=color)
    ax.fill_between(x, y, -1, color=color, alpha=0.7)

## Add details.
ax.set(xlim=(0.00,0.80), xticks=[], ylim=(5e-2), yticks=[])
sns.despine(left=True, bottom=True, top=True, right=True, ax=ax)

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
### Panel 3: scatterplot.
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

## Initialize axis.
ax = plt.subplot(panel_3[1:,:])

## Plot scatterplot.
ax.set(xlim=(0.00,0.80), ylim=(0.2,1.01))
sns.scatterplot(x=X[:,1], y=Y[:,1], hue=hue, palette=palette, legend=False, ax=ax)
sns.regplot(x=X[:,1], y=Y[:,1], scatter=False, ci=None, truncate=False, 
            color='k', line_kws=dict(lw=0.9, linestyle='--', zorder=-1), ax=ax)

## Add details.
ax.yaxis.tick_right()
ax.yaxis.set_label_position('right')
ax.set(xlabel='Self-Report Symptom Scores', ylabel='Accuracy')

## Add annotation.
rho = rvals[:,1].mean()
fpr = (pvals[:,1] < 0.05).mean()
annot = r'Mean $\hat{\rho}$ = %0.3f' %rho + '\nFPR = %0.3f' %fpr
ax.annotate(annot, (0,0), (0.98, 0.95), xycoords='axes fraction', ha='right', va='top', fontsize=14)

## Save figure.
plt.savefig(os.path.join('..','figures','intro.png'), dpi=180, transparent=True)
