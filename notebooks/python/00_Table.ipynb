# %%
import numpy as np
from pandas import read_csv

df = read_csv('silver-screen.csv')
df = df.replace({False:0,True:1})

# %%
df[['comprehension','missing','accuracy','variability','rt']].agg(['sum','mean'])
# Out:
#       comprehension    missing   accuracy  variability        rt
# sum        5.000000  10.000000  17.000000    15.000000  6.000000
# mean       0.131579   0.263158   0.447368     0.394737  0.157895

# %%
df.groupby(['behavior_screening','survey_screen']).doi.count()
# Out:
# behavior_screening  survey_screen
# 0                   0                 4
#                     1                 5
# 1                   0                26
#                     1                13
# Name: doi, dtype: int64

# %%
df
# Out:
#    coder                        citation  \
# 0     SZ         Albertella et al. 2019a
# 1     SZ         Albertella et al. 2019b
# 2     SZ             Beltzer et al. 2019
# 3     SZ            Carleton et al. 2016
# 4     SZ                 Choe et al 2019
# 5     SZ     Daniel-Watanabe et al. 2020
# 6     SZ           Eisenberg et al. 2018
# 7     SZ              Farmer et al. 2017
# 8     SZ             Harfman et al. 2019
# 9     SZ              Hunter et al. 2019
# 10    SZ         Imbault & Kuperman 2018
# 11    SZ                Kirk et al. 2020
# 12    SZ               Lamba et al. 2020
# 13    DB            Lockwood et al. 2017
# 14    SZ               Mazza et al. 2020
# 15    SZ            Patzelt et al. 2019a
# 16    SZ            Patzelt et al. 2019b
# 17    SZ               Phung et al. 2019
# 18    SZ             Raihani & Bell 2017
# 19    SZ             Raihani & Bell 2018
# 20    SZ                Reed et al. 2020
# 21    SZ              Rouhani & Niv 2019
# ...
