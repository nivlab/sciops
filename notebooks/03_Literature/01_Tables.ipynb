# %%
from pandas import read_csv

table = read_csv('data/table_1.csv').fillna(0)
table.filter(regex='survey').aggregate(['sum','mean'])
# Out:
#       survey_screen  survey_attention_check  \
# sum       19.000000               17.000000
# mean       0.387755                0.346939
#
#       survey_attention_check_instructed  survey_attention_check_unspecified  \
# sum                           10.000000                            5.000000
# mean                           0.204082                            0.102041
#
#       survey_unobtrusive  survey_total
# sum             4.000000     36.000000
# mean            0.081633      0.734694

# %%
table
# Out:
#    coder                        citation  \
# 0     SZ            Carleton et al. 2016
# 1     SZ                Reed et al. 2020
# 2     SZ               Safra et al. 2019
# 3     SZ              Siegal et al. 2020
# 4     SZ       Verdejo-Garcia et al 2020
# 5     SZ         Albertella et al. 2019a
# 6     SZ         Albertella et al. 2019b
# 7     SZ             Beltzer et al. 2019
# 8     SZ                 Choe et al 2019
# 9     SZ     Daniel-Watanabe et al. 2020
# 10    SZ           Eisenberg et al. 2018
# 11    SZ              Farmer et al. 2017
# 12    SZ             Harfman et al. 2019
# 13    DB              Hunter et al. 2019
# 14    SZ         Imbault & Kuperman 2018
# 15    SZ                Kirk et al. 2020
# 16    SZ               Lamba et al. 2020
# 17    SZ            Lockwood et al. 2017
# 18    SZ               Mazza et al. 2020
# 19    SZ            Patzelt et al. 2019a
# 20    SZ            Patzelt et al. 2019b
# 21    SZ               Phung et al. 2019
# ...
